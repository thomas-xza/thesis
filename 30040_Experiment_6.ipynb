# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import argparse, time, os, lzma, io
from datetime import datetime
from pathlib import Path

import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset, Subset
from torchvision import datasets
from torchvision.transforms import ToTensor
import torch.nn.functional as F
import torch.distributions as dist

import matplotlib.pyplot as plt

print(torch.__version__)
# Out:
# 2.10.0+cu128

# %%
##import pkgutil

##for module in pkgutil.iter_modules():
##  print(module.name)

# %%
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"

torch.set_default_dtype(torch.float64)

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class Pi_dataset(Dataset):

    def __init__(self, filename):

        with open(filename, 'r') as f:

            line_count = sum(1 for line in f)

            print(line_count)

            self.data = torch.zeros((line_count, 1), dtype=torch.float64)

            self.labels = torch.zeros((line_count, 1), dtype=torch.float64)

        with open(filename, 'r') as f:

            for i, line in enumerate(f):

                a = line.strip().split(',')

                self.data[i] = float(a[0])

                self.labels[i] = float(a[1])

    def __len__(self):

        return len(self.data)

    def __getitem__(self, idx):

        return self.data[idx], self.labels[idx]

# %%
class Linear_model_deterministic(nn.Module):

    def __init__(self, n: int, udist: tuple[int, int], random_seed: int):

        super().__init__()

        self.linear_relu_stack = nn.Sequential(
            nn.Linear(1, n),
            nn.ReLU(),
            nn.Dropout(p),
            nn.Linear(n, n),
            nn.ReLU(),
            nn.Dropout(p),
            nn.Linear(n, 1)
        )

        nn.init.uniform_(self.linear_relu_stack[0].weight, a=-udist[0], b=udist[1])
        nn.init.uniform_(self.linear_relu_stack[2].weight, a=-udist[0], b=udist[1])
        nn.init.uniform_(self.linear_relu_stack[4].weight, a=-udist[0], b=udist[1])

    def forward(self, x: torch.Tensor):

        logits = self.linear_relu_stack(x)

        out = torch.sigmoid(logits)

        return out, 0

# %%
def run_training_loop(model: nn.Module,
                      train_dl: DataLoader,
                      test_dl: DataLoader,
                      epochs: int,
                      filename: str,
                      kl_loss_ratio: float):

    ##  Define loss.

    loss = nn.BCELoss()

    ##  Define parameter optimisation mechanism.

    ##  optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

    # while time.time() - start_time < 300:

    ##  Train either for fixed period of time or fixed quantity of epochs.

    start_time = time.time()
    ##  Output training start time.

    print(datetime.now().strftime("%H:%M:%S"))

    ##  Run train-test sequence.

    for t in range(epochs):

        print(f"Training...")

        train(train_dl, model, loss, optimizer, kl_loss_ratio)

        print(f"Testing...")

        test(test_dl, model, loss, kl_loss_ratio)

    ##  Output training time.

    print(f"{time.time() - start_time}s")

    # print(model.state_dict())

    ##  Save model params to plaintext.

    # with open("model_params.post", "w") as f:

    #     state_dict = model.module.state_dict() if isinstance(model, nn.DataParallel) else model.state_dict()

    #     f.write(str(state_dict))

    ##  Generate timestamp and store weights for later loading back.

    print(filename)

    torch.save(model.state_dict(), filename)


def train(dl: DataLoader,
          model: nn.Module,
          loss: nn.Module,
          optimizer: torch.optim.Optimizer,
          kl_loss_ratio: float):

    ##  Put model into training mode; ensures gradient tracking.

    model.train()

    for batch, (X, y) in enumerate(dl):

        X, y = X.to(device), y.to(device)

        ##  Run X through model, generate prediction.

        y_hat, kl_model = model(X)

        ##  Calculate error of prediction.

        loss_res = (1 - kl_loss_ratio) * loss(y_hat, y) + (kl_loss_ratio * kl_model)

        ##  loss_res = loss(y_hat, y)

        ##  compute gradients numerically via backpropagation, back to
        ##  leaf nodes of graph.

        loss_res.backward()

        ##  Iterate parameters.

        optimizer.step()

        ##  Reset gradients within graph.

        optimizer.zero_grad()

        # optimizer.debug_off()

        if batch % 1000 == 0:

            pass

            # print(torch.stack([X, y, y_hat], dim=0).T)

            ##  It is not necessary to know the exact parameter
            ##  values, just that they are changing.

            # optimizer.debug_off()

            # print(model.state_dict().keys())

            # print(model.state_dict()['linear_relu_stack.0.weight_mu'].sum(),
            #       model.state_dict()['linear_relu_stack.0.rho_weight'].sum(),
            #       model.state_dict()['linear_relu_stack.0.mu_bias'].sum(),
            #       model.state_dict()['linear_relu_stack.0.rho_bias'].sum(),
            #       model.state_dict()['linear_relu_stack.2.weight_mu'].sum(),
            #       model.state_dict()['linear_relu_stack.2.rho_weight'].sum(),
            #       model.state_dict()['linear_relu_stack.2.mu_bias'].sum(),
            #       model.state_dict()['linear_relu_stack.2.rho_bias'].sum(),
            #       model.state_dict()['linear_relu_stack.4.weight_mu'].sum(),
            #       model.state_dict()['linear_relu_stack.4.rho_weight'].sum(),
            #       model.state_dict()['linear_relu_stack.4.mu_bias'].sum(),
            #       model.state_dict()['linear_relu_stack.4.rho_bias'].sum(),
            #       )

            # print(model.state_dict()['linear_relu_stack.0.weight_mu'][0])
            # print(model.state_dict()['linear_relu_stack.0.weight_mu'][0].grad)

            # print(torch.round(y_hat), y)

            # print(loss_res.item())

            # current = (batch + 1) * len(X)

            # print(f"[{current:>5d}/{len(train_dl.dataset):>5d}]")

            # print(f"loss_1: {loss_1:>7f}  [{current:>5d}/{size:>5d}]")


def test(dl: DataLoader, model: nn.Module, loss: nn.Module, kl_loss_ratio: float):

    ##  Trigger utilisation mode, whilst maintaining Dropout functionality.

    model.eval()

    for m in model.modules():

      if m.__class__.__name__.startswith('Dropout'):

        m.train()

    test_loss, correct = 0, 0

    with torch.no_grad():

        for X, y in dl:

            X, y = X.to(device), y.to(device)

            y_hat, kl_model = model(X)

            ##  Calculate error of prediction.

            ##  print("BCE: ", loss(y_hat, y))

            ##  print("KL: ", kl_model)

            loss_res = (1 - kl_loss_ratio) * loss(y_hat, y) + (kl_loss_ratio * kl_model)

            test_loss += loss_res.item()

            # correct += (y_hat.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= len(dl)

    # correct /= len(dl.dataset)

    print(f"{test_loss:>8f}")

# %%
def run_utilisation_loop_batch(model: nn.Module,
                               batch_name: str,
                               sample_quantity: int):

    print("loop batch")

    directory = Path('./params/')

    # Find all files with batch_name in filename

    for file in directory.glob(f"model_params*{batch_name}*xz"):

        print(str(file))

        if file.is_file():

            dist_metadata = str(file).split(batch_name)[-1].replace('.xz','')

            graph_filename = f"{batch_name}{dist_metadata}"

            params_path = f"./{str(file)}"

            run_utilisation_loop_once(model, params_path, graph_filename)

            # Do something with the file


def run_utilisation_loop_once(model: nn.Module, params_path: str, graph_filename: str, sample_quantity: int):

    ##  Decompress to memory.

    # with lzma.open(params_path, 'rb') as f:

    #     decompressed_data = f.read()

    ##  Load params.

    # checkpoint = torch.load(io.BytesIO(decompressed_data),

    checkpoint = torch.load(params_path,
                           weights_only = True,
                           map_location=torch.device('cpu')
                           )

    old_state_dict = checkpoint['state_dict'] if 'state_dict' in checkpoint else checkpoint

    print(old_state_dict)

    ##  Fix naming scheme and load module.

    model.load_state_dict(
                {k.replace('module.', '', 1): v for k, v in old_state_dict.items()}
    )

    ##  Trigger utilisation mode, whilst maintaining Dropout functionality.

    model.eval()

    for m in model.modules():

      if m.__class__.__name__.startswith('Dropout'):

        m.train()

    res = []

    interval = 1 / (2 ** 6)

    dl = DataLoader(
                TensorDataset(
                    torch.arange(1.57, 4.71 + interval, interval)
                ),
                batch_size = 1,
                shuffle = False
    )

    with torch.no_grad():

            ##################  Deterministic single-sample loop.

            # outputs_set = []

            # for batch, (X,) in enumerate(dl):

            #     X = X.to(device)

            #     # print(X)

            #     ##  Run X through model, generate prediction.

            #     y_hat, _ = model(X)

            #     print(X.item(), y_hat.item())

            #     outputs_set.append((X.item(), y_hat.squeeze(0).item()))

            ##################  MC-Dropout multi-sample loop.

            outputs_set = ()

            for batch, (X,) in enumerate(dl):

                X = X.to(device)

                # print(X)

                ##  Run X through model, generate prediction.

                sample_set = ()

                for _ in range(sample_quantity):

                    y_hat_sample, _ = model(X)

                    sample_set = sample_set + (y_hat_sample,)

                print(sample_set)

                ##  Take mean of samples.

                y_hat = torch.stack(sample_set).mean(dim=0)

                print(f"p({X.item()}) = {y_hat.item()}")

                ##  Store for later plotting

                outputs_set = outputs_set + ((X.item(), y_hat.squeeze(0).item()),)

            ##################

            x, y = zip(*outputs_set)

            plt.figure(figsize=(6, 4))

            # plt.plot(
            #             x, y,
            #             marker='o',
            #             markersize=4,          # small dots
            #             markerfacecolor='black',
            #             markeredgecolor='black',
            #             linewidth=0.8,         # thin connecting line
            #             color='black',
            #             label='Trajectory'
            # )

            plt.scatter(
                        x, y,
                        color='black',          # point colour
                        edgecolor='black',          # optional border around each marker
                        s=10,                       # marker size
                        label='Samples'
            )

            plt.xlabel('Input value')
            plt.ylabel('Probability of π classification')
            plt.grid(True, ls='--', lw=0.5, alpha=0.7)
            plt.tight_layout()

            plt.tight_layout()

            plt.savefig(f"{graph_filename}.pdf", dpi=300)
            #plt.show()

            plt.close()

            return graph_filename

# %%
def run_model(env: dict[str, str | int | float]):

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

    ##  Setup filename to store params to.

    filename = f"model_params_batch_{env['batch_n']}_epochs_{env['training_epochs']}_{env['params_name']}"

    file_path = os.path.join(*["/content", "drive", "MyDrive", filename])

    print(file_path)

    ##  Define model.

    print(env)

    if env["dropout_p"] == 0:

        print('Building deterministic model.')

        model = Linear_model_deterministic(
                    env["neurons_n"],
                    env["udist"],
                    env["random_seed"],
        ).to(device)

    else:

        print('Building MC dropout model.')

        model = Linear_model_mcdrop(
                    env["neurons_n"],
                    env["udist"],
                    env["random_seed"],
                    env["dropout_p"]
        ).to(device)

    ##  Ensure multiple GPUs used if available.

    if torch.cuda.device_count() > 1:

        print(f"Using {torch.cuda.device_count()} GPUs!")

        model = nn.DataParallel(model, device_ids=[0, 1])

    ##  Either load params or load training data.

    print(env)

    if env["params_load"] is not None:

        run_utilisation_loop_once(
                    model,
                    env["params_load"],
                    env["params_load"].split('/')[-1] + "_plot",
                    env["sample_quantity"]
        )

    elif env["params_load_batch"] is not None:

        run_utilisation_loop_batch(
                    model,
                    env["params_load_batch"],
                    env["sample_quantity"]
        )

    else:

        train_dl = DataLoader(
                    Subset(
                        Pi_dataset("/content/drive/MyDrive/modules_work/COMP30040/datasets/pi_dataset_40000.txt"),
                        range(40000)
                    ),
                    batch_size = env["batch_n"],
                    shuffle=True
        )

        test_dl = DataLoader(
                    Subset(
                        Pi_dataset("/content/drive/MyDrive/modules_work/COMP30040/datasets/pi_dataset_8000.txt"),
                        range(8000)
                    ),
                    batch_size = env["batch_n"],
                    shuffle=True
        )

        if env["params_checkpoint"] is not None:

            print("Loading checkpoint.")

            torch.load(env["params_checkpoint"])

        run_training_loop(model,
                          train_dl,
                          test_dl,
                          env["training_epochs"],
                          file_path,
                          env["kl_loss_ratio"])

# %%
class Linear_model_mcdrop(nn.Module):

    def __init__(self, n: int, udist: tuple[int, int], random_seed: int, p: float = 0.2):

        print(n)

        print(udist)

        super().__init__()

        self.linear_relu_stack = nn.Sequential(
            nn.Linear(1, n),
            nn.ReLU(),
            nn.Dropout(p),
            nn.Linear(n, n),
            nn.ReLU(),
            nn.Dropout(p),
            nn.Linear(n, 1)
        )

        nn.init.uniform_(self.linear_relu_stack[0].weight, a=-udist[0], b=udist[1])
        nn.init.uniform_(self.linear_relu_stack[3].weight, a=-udist[0], b=udist[1])
        nn.init.uniform_(self.linear_relu_stack[6].weight, a=-udist[0], b=udist[1])

    def forward(self, x: torch.Tensor):

        logits = self.linear_relu_stack(x)

        out = torch.sigmoid(logits)

        return out, 0

# %%
# env_train_det = {
#             "neurons_n": 1024,
#             "batch_n": 64,
#             "training_epochs": 50,
#             "params_name": "det",       ##  Filename to store params to.
#             "params_load": None,        ##  Filename to load specific set of params from.
#             "params_load_batch": None,  ##  Filename to wildcard match a multiple sets of params.
#             "random_seed": 239852,
#             "mu_w_init": 0.0,
#             "mu_b_init": 0.0,
#             "rho_w_init": 0.0,
#             "rho_b_init": 0.0,
#             "kl_loss_ratio": 0.0,       ##  Ratio to consider KL-divergence loss during sum of loss functions.
#             "udist": (0.1, 0.1)         ##  Uniform distribution params, in the case of deterministic model.
# }

env_train_mcdrop = {
            "neurons_n": 1024,
            "batch_n": 256,
            "training_epochs": 2,
            "params_name": "mcdrop_0.2",  ##  Filename to store params to.
            "params_load": None,          ##  Filename to load specific set of params from, for utilisation.
            "params_load_batch": None,    ##  Filename to wildcard match a multiple sets of params.
            "params_checkpoint": None,    ##  "/content/drive/MyDrive/model_params_batch_16_epochs_34_mcdrop",
            "random_seed": 239852,
            "mu_w_init": 0,
            "mu_b_init": 0,
            "rho_w_init": 0,
            "rho_b_init": 0,
            "kl_loss_ratio": 0,           ##  Ratio to consider KL-divergence loss during sum of loss functions.
            "udist": (0.2, 0.2),          ##  Uniform distribution params, if not (0, 0) will trigger deterministic model.
            "dropout_p": 0.8
}

#for k, v in env.items():
#            print(f"{k}: {v}")

torch.manual_seed(env_train_mcdrop["random_seed"])

udist_distribs = tuple(map(lambda x: 0.125 * x, tuple(range(1, 4))))

for udist in udist_distribs:

  for seed in (5453, 7876974563457, 67498896):

    env_train_mcdrop_tmp = env_train_mcdrop.copy()

    env_train_mcdrop_tmp["random_seed"] = seed

    env_train_mcdrop_tmp["udist"] = (udist, udist)

    env_train_mcdrop_tmp["params_name"] = f"mcdrop_seed_{seed}_udist_{udist}"

    run_model(env=env_train_mcdrop_tmp)
# Out:
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_5453_udist_0.125
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_5453_udist_0.125', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 5453, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.125, 0.125), 'dropout_p': 0.8}
# Building MC dropout model.
# 1024
# (0.125, 0.125)
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_5453_udist_0.125', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 5453, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.125, 0.125), 'dropout_p': 0.8}
# 40000
# 8000
# 09:13:33
# Training...
# Testing...
# 0.599539
# Training...
# Testing...
# 0.368715
# 2.0941100120544434s
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_5453_udist_0.125
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_7876974563457_udist_0.125
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_7876974563457_udist_0.125', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 7876974563457, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.125, 0.125), 'dropout_p': 0.8}
# Building MC dropout model.
# 1024
# (0.125, 0.125)
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_7876974563457_udist_0.125', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 7876974563457, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.125, 0.125), 'dropout_p': 0.8}
# 40000
# 8000
# 09:13:36
# Training...
# Testing...
# 0.598093
# Training...
# Testing...
# 0.376704
# 2.23134183883667s
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_7876974563457_udist_0.125
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_67498896_udist_0.125
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_67498896_udist_0.125', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 67498896, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.125, 0.125), 'dropout_p': 0.8}
# Building MC dropout model.
# 1024
# (0.125, 0.125)
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_67498896_udist_0.125', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 67498896, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.125, 0.125), 'dropout_p': 0.8}
# 40000
# 8000
# 09:13:39
# Training...
# Testing...
# 0.631806
# Training...
# Testing...
# 0.374673
# 2.0929114818573s
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_67498896_udist_0.125
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_5453_udist_0.25
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_5453_udist_0.25', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 5453, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.25, 0.25), 'dropout_p': 0.8}
# Building MC dropout model.
# 1024
# (0.25, 0.25)
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_5453_udist_0.25', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 5453, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.25, 0.25), 'dropout_p': 0.8}
# 40000
# 8000
# 09:13:41
# Training...
# Testing...
# 4.709285
# Training...
# Testing...
# 1.448689
# 2.093248128890991s
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_5453_udist_0.25
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_7876974563457_udist_0.25
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_7876974563457_udist_0.25', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 7876974563457, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.25, 0.25), 'dropout_p': 0.8}
# Building MC dropout model.
# 1024
# (0.25, 0.25)
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_7876974563457_udist_0.25', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 7876974563457, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.25, 0.25), 'dropout_p': 0.8}
# 40000
# 8000
# 09:13:44
# Training...
# Testing...
# 3.890079
# Training...
# Testing...
# 1.234751
# 2.23954439163208s
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_7876974563457_udist_0.25
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_67498896_udist_0.25
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_67498896_udist_0.25', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 67498896, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.25, 0.25), 'dropout_p': 0.8}
# Building MC dropout model.
# 1024
# (0.25, 0.25)
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_67498896_udist_0.25', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 67498896, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.25, 0.25), 'dropout_p': 0.8}
# 40000
# 8000
# 09:13:47
# Training...
# Testing...
# 3.426095
# Training...
# Testing...
# 1.018841
# 2.0944275856018066s
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_67498896_udist_0.25
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_5453_udist_0.375
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_5453_udist_0.375', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 5453, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.375, 0.375), 'dropout_p': 0.8}
# Building MC dropout model.
# 1024
# (0.375, 0.375)
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_5453_udist_0.375', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 5453, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.375, 0.375), 'dropout_p': 0.8}
# 40000
# 8000
# 09:13:50
# Training...
# Testing...
# 25.731774
# Training...
# Testing...
# 16.090395
# 2.0967185497283936s
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_5453_udist_0.375
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_7876974563457_udist_0.375
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_7876974563457_udist_0.375', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 7876974563457, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.375, 0.375), 'dropout_p': 0.8}
# Building MC dropout model.
# 1024
# (0.375, 0.375)
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_7876974563457_udist_0.375', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 7876974563457, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.375, 0.375), 'dropout_p': 0.8}
# 40000
# 8000
# 09:13:52
# Training...
# Testing...
# 28.568613
# Training...
# Testing...
# 20.728042
# 2.2297861576080322s
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_7876974563457_udist_0.375
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_67498896_udist_0.375
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_67498896_udist_0.375', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 67498896, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.375, 0.375), 'dropout_p': 0.8}
# Building MC dropout model.
# 1024
# (0.375, 0.375)
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': 'mcdrop_seed_67498896_udist_0.375', 'params_load': None, 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 67498896, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.375, 0.375), 'dropout_p': 0.8}
# 40000
# 8000
# 09:13:55
# Training...
# Testing...
# 25.680822
# Training...
# Testing...
# 17.243855
# 2.098100423812866s
# /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_67498896_udist_0.375

# %%
filename_mcdrop = f"/content/drive/MyDrive/model_params_batch_{env_train_mcdrop['batch_n']}_epochs_{env_train_mcdrop['training_epochs']}_{env_train_mcdrop['params_name']}"

env_load_mcdrop = {
            "params_name": None,
            "params_load": filename_mcdrop,
            "params_load_batch": None,
            "sample_quantity": 50
}

env_utilise_mcdrop = env_train_mcdrop | env_load_mcdrop

for udist in udist_distribs:

  for seed in (5453, 7876974563457, 67498896):

    env_utilise_mcdrop_tmp = env_train_mcdrop.copy()

    env_utilise_mcdrop_tmp = env_train_mcdrop_tmp | env_load_mcdrop

    env_utilise_mcdrop_tmp["params_load"] = f"/content/drive/MyDrive/model_params_batch_{env_train_mcdrop['batch_n']}_epochs_{env_train_mcdrop['training_epochs']}_mcdrop_seed_{seed}_udist_{udist}"

    for k, v in env_utilise_mcdrop_tmp.items():
            print(f"{k}: {v}")

    run_model(env_utilise_mcdrop_tmp)
# Out:
# neurons_n: 1024
# batch_n: 256
# training_epochs: 2
# params_name: None
# params_load: /content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_5453_udist_0.125
# params_load_batch: None
# params_checkpoint: None
# random_seed: 67498896
# mu_w_init: 0
# mu_b_init: 0
# rho_w_init: 0
# rho_b_init: 0
# kl_loss_ratio: 0
# udist: (0.375, 0.375)
# dropout_p: 0.8
# sample_quantity: 50
# /content/drive/MyDrive/model_params_batch_256_epochs_2_None
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': None, 'params_load': '/content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_5453_udist_0.125', 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 67498896, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.375, 0.375), 'dropout_p': 0.8, 'sample_quantity': 50}
# Building MC dropout model.
# 1024
# (0.375, 0.375)
# {'neurons_n': 1024, 'batch_n': 256, 'training_epochs': 2, 'params_name': None, 'params_load': '/content/drive/MyDrive/model_params_batch_256_epochs_2_mcdrop_seed_5453_udist_0.125', 'params_load_batch': None, 'params_checkpoint': None, 'random_seed': 67498896, 'mu_w_init': 0, 'mu_b_init': 0, 'rho_w_init': 0, 'rho_b_init': 0, 'kl_loss_ratio': 0, 'udist': (0.375, 0.375), 'dropout_p': 0.8, 'sample_quantity': 50}
# OrderedDict({'linear_relu_stack.0.weight': tensor([[ 0.0159],
#         [-0.0013],
#         [ 0.0170],
#         ...,
#         [-0.0548],
#         [-0.0853],
#         [ 0.0839]]), 'linear_relu_stack.0.bias': tensor([ 0.5647, -0.5022,  0.8846,  ...,  0.6747,  0.6431, -0.7910]), 'linear_relu_stack.3.weight': tensor([[-0.0274, -0.0911, -0.0498,  ..., -0.1003,  0.0911, -0.0512],
#         [-0.1049,  0.1165,  0.0406,  ..., -0.1211, -0.1214,  0.0770],
#         [-0.0373, -0.0375,  0.0170,  ..., -0.0447, -0.1242, -0.0047],
#         ...,
#         [-0.0094,  0.0277,  0.0278,  ..., -0.1312, -0.0655, -0.0200],
#         [-0.0164, -0.0427,  0.0048,  ..., -0.0553, -0.1036, -0.0532],
#         [-0.0709,  0.0042,  0.0521,  ..., -0.0420,  0.0064,  0.0069]]), 'linear_relu_stack.3.bias': tensor([-0.0357, -0.0369,  0.0369,  ...,  0.0102, -0.0265, -0.0398]), 'linear_relu_stack.6.weight': tensor([[ 0.0525, -0.0506,  0.0298,  ..., -0.0327,  0.0789, -0.0567]]), 'linear_relu_stack.6.bias': tensor([0.0011])})
# (tensor([0.0215], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0029], device='cuda:0'), tensor([0.0053], device='cuda:0'), tensor([0.0168], device='cuda:0'), tensor([8.5158e-05], device='cuda:0'), tensor([0.2335], device='cuda:0'), tensor([0.0026], device='cuda:0'), tensor([3.9188e-07], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0299], device='cuda:0'), tensor([0.0029], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0101], device='cuda:0'), tensor([0.0275], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0084], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.0034], device='cuda:0'), tensor([0.0102], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([5.7108e-05], device='cuda:0'), tensor([0.0731], device='cuda:0'), tensor([0.0038], device='cuda:0'), tensor([0.0023], device='cuda:0'), tensor([9.5162e-05], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0029], device='cuda:0'), tensor([0.0276], device='cuda:0'), tensor([0.0743], device='cuda:0'), tensor([0.0064], device='cuda:0'), tensor([5.0696e-05], device='cuda:0'), tensor([0.0029], device='cuda:0'), tensor([0.0124], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0012], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0014], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.1026], device='cuda:0'), tensor([0.0015], device='cuda:0'), tensor([1.5483e-05], device='cuda:0'), tensor([8.0127e-05], device='cuda:0'), tensor([0.0499], device='cuda:0'), tensor([0.0010], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0016], device='cuda:0'), tensor([8.9359e-05], device='cuda:0'), tensor([0.2744], device='cuda:0'))
# p(1.57) = 0.020372579067334754
# (tensor([0.0005], device='cuda:0'), tensor([0.0022], device='cuda:0'), tensor([3.9509e-06], device='cuda:0'), tensor([0.0065], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0164], device='cuda:0'), tensor([0.0069], device='cuda:0'), tensor([0.0027], device='cuda:0'), tensor([0.0094], device='cuda:0'), tensor([0.0049], device='cuda:0'), tensor([0.0040], device='cuda:0'), tensor([0.0040], device='cuda:0'), tensor([0.0013], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0465], device='cuda:0'), tensor([0.0035], device='cuda:0'), tensor([0.0113], device='cuda:0'), tensor([0.0102], device='cuda:0'), tensor([0.0087], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([6.8266e-05], device='cuda:0'), tensor([3.8821e-05], device='cuda:0'), tensor([0.0021], device='cuda:0'), tensor([2.7874e-05], device='cuda:0'), tensor([5.8578e-05], device='cuda:0'), tensor([0.0054], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0023], device='cuda:0'), tensor([0.0017], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.0069], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0055], device='cuda:0'), tensor([0.0169], device='cuda:0'), tensor([0.0020], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.0120], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0057], device='cuda:0'), tensor([0.0233], device='cuda:0'), tensor([0.0016], device='cuda:0'), tensor([4.8425e-05], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0164], device='cuda:0'), tensor([0.0097], device='cuda:0'), tensor([0.0187], device='cuda:0'), tensor([0.1239], device='cuda:0'))
# p(1.585625) = 0.007963128792822679
# (tensor([0.0018], device='cuda:0'), tensor([6.7941e-05], device='cuda:0'), tensor([5.7483e-05], device='cuda:0'), tensor([0.0061], device='cuda:0'), tensor([0.0019], device='cuda:0'), tensor([0.0103], device='cuda:0'), tensor([0.0016], device='cuda:0'), tensor([0.1197], device='cuda:0'), tensor([3.4533e-06], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0036], device='cuda:0'), tensor([0.0340], device='cuda:0'), tensor([0.0070], device='cuda:0'), tensor([1.6618e-05], device='cuda:0'), tensor([4.9331e-05], device='cuda:0'), tensor([0.0132], device='cuda:0'), tensor([0.0015], device='cuda:0'), tensor([0.0313], device='cuda:0'), tensor([0.0327], device='cuda:0'), tensor([0.0217], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0054], device='cuda:0'), tensor([0.1124], device='cuda:0'), tensor([7.1563e-05], device='cuda:0'), tensor([0.0147], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.0046], device='cuda:0'), tensor([0.0134], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.0029], device='cuda:0'), tensor([0.0089], device='cuda:0'), tensor([0.0011], device='cuda:0'), tensor([0.0367], device='cuda:0'), tensor([0.0136], device='cuda:0'), tensor([0.4321], device='cuda:0'), tensor([0.0567], device='cuda:0'), tensor([0.0952], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0115], device='cuda:0'), tensor([0.0062], device='cuda:0'), tensor([0.2037], device='cuda:0'), tensor([0.0046], device='cuda:0'), tensor([0.0062], device='cuda:0'), tensor([0.0018], device='cuda:0'), tensor([9.2639e-05], device='cuda:0'), tensor([0.0504], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.0020], device='cuda:0'))
# p(1.60125) = 0.027484974642523037
# (tensor([0.0269], device='cuda:0'), tensor([4.8395e-06], device='cuda:0'), tensor([0.0501], device='cuda:0'), tensor([0.0101], device='cuda:0'), tensor([0.0055], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0232], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0058], device='cuda:0'), tensor([0.0049], device='cuda:0'), tensor([0.0454], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0020], device='cuda:0'), tensor([0.0110], device='cuda:0'), tensor([7.6823e-05], device='cuda:0'), tensor([0.0175], device='cuda:0'), tensor([0.0419], device='cuda:0'), tensor([0.0014], device='cuda:0'), tensor([0.0037], device='cuda:0'), tensor([9.8928e-05], device='cuda:0'), tensor([0.1671], device='cuda:0'), tensor([0.0028], device='cuda:0'), tensor([1.4300e-05], device='cuda:0'), tensor([0.0054], device='cuda:0'), tensor([0.0244], device='cuda:0'), tensor([0.0547], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.3096], device='cuda:0'), tensor([0.0046], device='cuda:0'), tensor([7.0684e-05], device='cuda:0'), tensor([0.0055], device='cuda:0'), tensor([0.0037], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([1.0180e-05], device='cuda:0'), tensor([0.0044], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0197], device='cuda:0'), tensor([0.0144], device='cuda:0'), tensor([0.0011], device='cuda:0'), tensor([0.0028], device='cuda:0'), tensor([7.3730e-05], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0128], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0001], device='cuda:0'))
# p(1.616875) = 0.017761138149575476
# (tensor([0.0398], device='cuda:0'), tensor([0.0010], device='cuda:0'), tensor([0.0321], device='cuda:0'), tensor([0.0047], device='cuda:0'), tensor([0.0367], device='cuda:0'), tensor([0.0040], device='cuda:0'), tensor([0.0036], device='cuda:0'), tensor([0.0030], device='cuda:0'), tensor([0.0145], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0042], device='cuda:0'), tensor([0.1390], device='cuda:0'), tensor([0.2100], device='cuda:0'), tensor([0.0954], device='cuda:0'), tensor([0.0079], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0086], device='cuda:0'), tensor([0.0031], device='cuda:0'), tensor([0.0021], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0016], device='cuda:0'), tensor([0.0012], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([5.1405e-05], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.0100], device='cuda:0'), tensor([0.3823], device='cuda:0'), tensor([1.5691e-06], device='cuda:0'), tensor([3.3084e-05], device='cuda:0'), tensor([2.4265e-05], device='cuda:0'), tensor([0.9204], device='cuda:0'), tensor([3.1985e-05], device='cuda:0'), tensor([0.0028], device='cuda:0'), tensor([0.0052], device='cuda:0'), tensor([0.0024], device='cuda:0'), tensor([0.0528], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0175], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([1.9315e-05], device='cuda:0'), tensor([0.0800], device='cuda:0'), tensor([9.1958e-06], device='cuda:0'), tensor([0.0056], device='cuda:0'), tensor([0.0404], device='cuda:0'), tensor([0.0669], device='cuda:0'), tensor([0.0033], device='cuda:0'), tensor([0.0093], device='cuda:0'), tensor([0.0119], device='cuda:0'), tensor([0.0028], device='cuda:0'), tensor([0.0004], device='cuda:0'))
# p(1.6325) = 0.044600965970583044
# (tensor([0.0754], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0265], device='cuda:0'), tensor([0.0229], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0119], device='cuda:0'), tensor([0.0156], device='cuda:0'), tensor([0.0013], device='cuda:0'), tensor([0.0017], device='cuda:0'), tensor([0.0066], device='cuda:0'), tensor([0.0026], device='cuda:0'), tensor([0.0743], device='cuda:0'), tensor([0.0278], device='cuda:0'), tensor([0.0251], device='cuda:0'), tensor([0.0094], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([1.8196e-05], device='cuda:0'), tensor([0.0032], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.5937], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0125], device='cuda:0'), tensor([0.0021], device='cuda:0'), tensor([0.0028], device='cuda:0'), tensor([0.0010], device='cuda:0'), tensor([0.0275], device='cuda:0'), tensor([6.4545e-05], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([0.0132], device='cuda:0'), tensor([4.1984e-05], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.0113], device='cuda:0'), tensor([0.0039], device='cuda:0'), tensor([0.0012], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0079], device='cuda:0'), tensor([0.0073], device='cuda:0'), tensor([0.0046], device='cuda:0'), tensor([0.2250], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0069], device='cuda:0'), tensor([3.8497e-05], device='cuda:0'), tensor([0.0125], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.0015], device='cuda:0'), tensor([0.0017], device='cuda:0'), tensor([2.2215e-05], device='cuda:0'))
# p(1.648125) = 0.024933649066258612
# (tensor([0.0008], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0483], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([2.2155e-05], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([1.8379e-05], device='cuda:0'), tensor([0.0021], device='cuda:0'), tensor([0.0111], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0889], device='cuda:0'), tensor([0.0399], device='cuda:0'), tensor([0.0081], device='cuda:0'), tensor([4.8674e-05], device='cuda:0'), tensor([4.0467e-06], device='cuda:0'), tensor([0.0031], device='cuda:0'), tensor([0.0012], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0394], device='cuda:0'), tensor([8.1657e-05], device='cuda:0'), tensor([0.0724], device='cuda:0'), tensor([0.0476], device='cuda:0'), tensor([0.0076], device='cuda:0'), tensor([4.9650e-05], device='cuda:0'), tensor([8.2928e-05], device='cuda:0'), tensor([1.2860e-05], device='cuda:0'), tensor([0.0041], device='cuda:0'), tensor([0.0030], device='cuda:0'), tensor([0.0812], device='cuda:0'), tensor([0.0093], device='cuda:0'), tensor([0.4247], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0101], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.0024], device='cuda:0'), tensor([0.1029], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0017], device='cuda:0'), tensor([0.0096], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.0022], device='cuda:0'), tensor([0.4385], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([0.0011], device='cuda:0'), tensor([0.0461], device='cuda:0'), tensor([0.0056], device='cuda:0'), tensor([0.0020], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0671], device='cuda:0'))
# p(1.66375) = 0.0317487396773333
# (tensor([0.0005], device='cuda:0'), tensor([0.0210], device='cuda:0'), tensor([0.0752], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0156], device='cuda:0'), tensor([0.0045], device='cuda:0'), tensor([0.0790], device='cuda:0'), tensor([0.0046], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0260], device='cuda:0'), tensor([0.5348], device='cuda:0'), tensor([0.0087], device='cuda:0'), tensor([0.0820], device='cuda:0'), tensor([0.0039], device='cuda:0'), tensor([0.2496], device='cuda:0'), tensor([0.0184], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0025], device='cuda:0'), tensor([0.0012], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([0.0135], device='cuda:0'), tensor([0.0115], device='cuda:0'), tensor([0.0080], device='cuda:0'), tensor([0.0019], device='cuda:0'), tensor([0.0183], device='cuda:0'), tensor([0.0187], device='cuda:0'), tensor([1.1456e-05], device='cuda:0'), tensor([0.0042], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0137], device='cuda:0'), tensor([0.0045], device='cuda:0'), tensor([0.0199], device='cuda:0'), tensor([0.0262], device='cuda:0'), tensor([0.0148], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0020], device='cuda:0'), tensor([0.0129], device='cuda:0'), tensor([0.0057], device='cuda:0'), tensor([0.0501], device='cuda:0'), tensor([0.0106], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0049], device='cuda:0'), tensor([0.0048], device='cuda:0'), tensor([0.0402], device='cuda:0'), tensor([9.9855e-05], device='cuda:0'), tensor([0.0386], device='cuda:0'), tensor([0.0061], device='cuda:0'), tensor([1.1843e-05], device='cuda:0'), tensor([0.1621], device='cuda:0'), tensor([0.0074], device='cuda:0'))
# p(1.679375) = 0.03261148311467576
# (tensor([0.0009], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([2.6160e-05], device='cuda:0'), tensor([9.0721e-05], device='cuda:0'), tensor([9.6588e-07], device='cuda:0'), tensor([0.6336], device='cuda:0'), tensor([0.2485], device='cuda:0'), tensor([0.0154], device='cuda:0'), tensor([0.0011], device='cuda:0'), tensor([4.4913e-05], device='cuda:0'), tensor([0.0012], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([4.6153e-05], device='cuda:0'), tensor([0.0053], device='cuda:0'), tensor([0.1351], device='cuda:0'), tensor([0.0343], device='cuda:0'), tensor([7.0128e-05], device='cuda:0'), tensor([0.0049], device='cuda:0'), tensor([2.3174e-05], device='cuda:0'), tensor([0.0063], device='cuda:0'), tensor([0.0476], device='cuda:0'), tensor([0.0036], device='cuda:0'), tensor([0.0377], device='cuda:0'), tensor([0.0645], device='cuda:0'), tensor([0.0019], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0194], device='cuda:0'), tensor([0.0083], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.5794], device='cuda:0'), tensor([0.1347], device='cuda:0'), tensor([0.6266], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.0550], device='cuda:0'), tensor([0.0022], device='cuda:0'), tensor([2.2154e-05], device='cuda:0'), tensor([0.0053], device='cuda:0'), tensor([0.0294], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0023], device='cuda:0'), tensor([0.0853], device='cuda:0'), tensor([0.1814], device='cuda:0'), tensor([0.0027], device='cuda:0'), tensor([0.3943], device='cuda:0'), tensor([0.0016], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([6.5389e-05], device='cuda:0'), tensor([4.2842e-06], device='cuda:0'), tensor([0.0613], device='cuda:0'), tensor([4.9623e-05], device='cuda:0'))
# p(1.695) = 0.06869258015544485
# (tensor([0.0366], device='cuda:0'), tensor([0.0036], device='cuda:0'), tensor([0.0196], device='cuda:0'), tensor([0.0150], device='cuda:0'), tensor([0.0166], device='cuda:0'), tensor([0.0376], device='cuda:0'), tensor([0.0100], device='cuda:0'), tensor([0.0270], device='cuda:0'), tensor([0.0011], device='cuda:0'), tensor([0.0031], device='cuda:0'), tensor([0.0120], device='cuda:0'), tensor([0.0023], device='cuda:0'), tensor([0.0099], device='cuda:0'), tensor([8.0999e-06], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([0.0467], device='cuda:0'), tensor([0.1900], device='cuda:0'), tensor([0.0112], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0039], device='cuda:0'), tensor([0.0010], device='cuda:0'), tensor([0.0919], device='cuda:0'), tensor([9.1741e-05], device='cuda:0'), tensor([0.2883], device='cuda:0'), tensor([0.0064], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.0340], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0071], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([2.2345e-05], device='cuda:0'), tensor([0.0253], device='cuda:0'), tensor([0.0023], device='cuda:0'), tensor([2.8014e-05], device='cuda:0'), tensor([0.0065], device='cuda:0'), tensor([0.0085], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0032], device='cuda:0'), tensor([0.0046], device='cuda:0'), tensor([0.0056], device='cuda:0'), tensor([0.0625], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([3.5602e-05], device='cuda:0'), tensor([0.0011], device='cuda:0'), tensor([8.9040e-05], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0015], device='cuda:0'), tensor([0.0017], device='cuda:0'), tensor([0.0034], device='cuda:0'))
# p(1.710625) = 0.020119026794303697
# (tensor([0.0002], device='cuda:0'), tensor([0.0230], device='cuda:0'), tensor([0.0018], device='cuda:0'), tensor([0.0029], device='cuda:0'), tensor([0.0027], device='cuda:0'), tensor([0.0030], device='cuda:0'), tensor([0.0365], device='cuda:0'), tensor([0.3727], device='cuda:0'), tensor([0.0280], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0017], device='cuda:0'), tensor([0.0016], device='cuda:0'), tensor([0.0165], device='cuda:0'), tensor([5.9710e-05], device='cuda:0'), tensor([0.0068], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0152], device='cuda:0'), tensor([0.6388], device='cuda:0'), tensor([0.0053], device='cuda:0'), tensor([0.0035], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([5.6004e-05], device='cuda:0'), tensor([0.0055], device='cuda:0'), tensor([0.1980], device='cuda:0'), tensor([0.0250], device='cuda:0'), tensor([0.0095], device='cuda:0'), tensor([0.0034], device='cuda:0'), tensor([0.0011], device='cuda:0'), tensor([0.0019], device='cuda:0'), tensor([0.0166], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.0034], device='cuda:0'), tensor([0.0037], device='cuda:0'), tensor([0.0021], device='cuda:0'), tensor([0.0053], device='cuda:0'), tensor([0.0159], device='cuda:0'), tensor([0.0165], device='cuda:0'), tensor([0.0098], device='cuda:0'), tensor([0.0098], device='cuda:0'), tensor([0.3051], device='cuda:0'), tensor([0.2496], device='cuda:0'), tensor([0.1573], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0097], device='cuda:0'), tensor([0.0231], device='cuda:0'), tensor([0.0139], device='cuda:0'), tensor([0.3198], device='cuda:0'), tensor([0.3364], device='cuda:0'), tensor([0.0035], device='cuda:0'), tensor([0.0164], device='cuda:0'))
# p(1.72625) = 0.05849584507753133
# (tensor([0.0396], device='cuda:0'), tensor([0.1656], device='cuda:0'), tensor([0.0318], device='cuda:0'), tensor([0.0026], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0102], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0041], device='cuda:0'), tensor([0.0045], device='cuda:0'), tensor([0.0040], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([1.9732e-05], device='cuda:0'), tensor([0.4954], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0019], device='cuda:0'), tensor([5.4691e-05], device='cuda:0'), tensor([0.0152], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.1768], device='cuda:0'), tensor([0.0302], device='cuda:0'), tensor([0.1131], device='cuda:0'), tensor([0.0044], device='cuda:0'), tensor([0.0825], device='cuda:0'), tensor([0.0446], device='cuda:0'), tensor([0.0019], device='cuda:0'), tensor([0.1628], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0034], device='cuda:0'), tensor([0.3791], device='cuda:0'), tensor([0.0223], device='cuda:0'), tensor([0.0020], device='cuda:0'), tensor([0.0067], device='cuda:0'), tensor([0.0026], device='cuda:0'), tensor([0.0212], device='cuda:0'), tensor([0.0228], device='cuda:0'), tensor([0.0116], device='cuda:0'), tensor([6.7120e-06], device='cuda:0'), tensor([0.0147], device='cuda:0'), tensor([0.4472], device='cuda:0'), tensor([8.9608e-05], device='cuda:0'), tensor([0.2138], device='cuda:0'), tensor([0.0017], device='cuda:0'), tensor([0.0059], device='cuda:0'), tensor([0.0192], device='cuda:0'))
# p(1.741875) = 0.051411923540189995
# (tensor([0.1058], device='cuda:0'), tensor([0.0024], device='cuda:0'), tensor([3.5741e-05], device='cuda:0'), tensor([0.0574], device='cuda:0'), tensor([0.0043], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([0.0980], device='cuda:0'), tensor([0.0241], device='cuda:0'), tensor([0.0016], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0034], device='cuda:0'), tensor([0.0039], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.2838], device='cuda:0'), tensor([0.0082], device='cuda:0'), tensor([0.0570], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0646], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0211], device='cuda:0'), tensor([0.0462], device='cuda:0'), tensor([0.0122], device='cuda:0'), tensor([0.0136], device='cuda:0'), tensor([0.0776], device='cuda:0'), tensor([0.1301], device='cuda:0'), tensor([0.0038], device='cuda:0'), tensor([0.6064], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0031], device='cuda:0'), tensor([0.2857], device='cuda:0'), tensor([0.0015], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0124], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0281], device='cuda:0'), tensor([0.0021], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([0.0031], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.2828], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0159], device='cuda:0'), tensor([0.0036], device='cuda:0'), tensor([0.0330], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([3.9626e-05], device='cuda:0'), tensor([0.0112], device='cuda:0'), tensor([0.0229], device='cuda:0'), tensor([0.0007], device='cuda:0'))
# p(1.7575) = 0.04675244675357698
# (tensor([5.6413e-05], device='cuda:0'), tensor([0.0018], device='cuda:0'), tensor([0.0999], device='cuda:0'), tensor([0.0020], device='cuda:0'), tensor([0.0055], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0362], device='cuda:0'), tensor([0.0014], device='cuda:0'), tensor([5.4579e-05], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([0.7755], device='cuda:0'), tensor([0.0167], device='cuda:0'), tensor([0.1199], device='cuda:0'), tensor([6.2614e-05], device='cuda:0'), tensor([0.0038], device='cuda:0'), tensor([0.0808], device='cuda:0'), tensor([0.1640], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0067], device='cuda:0'), tensor([2.6496e-06], device='cuda:0'), tensor([0.0026], device='cuda:0'), tensor([0.0014], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0036], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0325], device='cuda:0'), tensor([0.0179], device='cuda:0'), tensor([0.0116], device='cuda:0'), tensor([0.0025], device='cuda:0'), tensor([0.0214], device='cuda:0'), tensor([0.0041], device='cuda:0'), tensor([0.0026], device='cuda:0'), tensor([0.0095], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([5.6746e-06], device='cuda:0'), tensor([0.0137], device='cuda:0'), tensor([0.0070], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([3.5178e-05], device='cuda:0'), tensor([0.0260], device='cuda:0'), tensor([0.0103], device='cuda:0'), tensor([0.0016], device='cuda:0'), tensor([8.1792e-05], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0745], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0106], device='cuda:0'), tensor([2.4992e-05], device='cuda:0'))
# p(1.773125) = 0.03145227835110468
# (tensor([0.0087], device='cuda:0'), tensor([0.0834], device='cuda:0'), tensor([6.9029e-05], device='cuda:0'), tensor([0.2704], device='cuda:0'), tensor([0.0013], device='cuda:0'), tensor([0.0015], device='cuda:0'), tensor([0.0227], device='cuda:0'), tensor([0.0239], device='cuda:0'), tensor([0.0020], device='cuda:0'), tensor([0.0055], device='cuda:0'), tensor([0.0338], device='cuda:0'), tensor([0.0016], device='cuda:0'), tensor([0.0012], device='cuda:0'), tensor([0.0129], device='cuda:0'), tensor([0.0019], device='cuda:0'), tensor([0.0032], device='cuda:0'), tensor([0.0414], device='cuda:0'), tensor([0.0078], device='cuda:0'), tensor([0.0102], device='cuda:0'), tensor([0.0025], device='cuda:0'), tensor([0.0325], device='cuda:0'), tensor([0.0013], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0074], device='cuda:0'), tensor([0.0022], device='cuda:0'), tensor([6.0833e-05], device='cuda:0'), tensor([0.0032], device='cuda:0'), tensor([0.0026], device='cuda:0'), tensor([0.0068], device='cuda:0'), tensor([0.0433], device='cuda:0'), tensor([0.0063], device='cuda:0'), tensor([0.0012], device='cuda:0'), tensor([0.0172], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0161], device='cuda:0'), tensor([8.2242e-05], device='cuda:0'), tensor([0.0219], device='cuda:0'), tensor([0.0247], device='cuda:0'), tensor([0.0031], device='cuda:0'), tensor([2.5456e-05], device='cuda:0'), tensor([0.1967], device='cuda:0'), tensor([0.0020], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0504], device='cuda:0'), tensor([0.1099], device='cuda:0'), tensor([0.0060], device='cuda:0'), tensor([6.4146e-06], device='cuda:0'), tensor([0.3450], device='cuda:0'), tensor([0.0007], device='cuda:0'))
# p(1.78875) = 0.02876693032314749
# (tensor([0.0105], device='cuda:0'), tensor([0.0058], device='cuda:0'), tensor([0.1097], device='cuda:0'), tensor([0.0157], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.1408], device='cuda:0'), tensor([0.2778], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0023], device='cuda:0'), tensor([0.0591], device='cuda:0'), tensor([0.0016], device='cuda:0'), tensor([9.0122e-05], device='cuda:0'), tensor([3.8881e-05], device='cuda:0'), tensor([0.0021], device='cuda:0'), tensor([9.5043e-05], device='cuda:0'), tensor([0.0896], device='cuda:0'), tensor([0.0195], device='cuda:0'), tensor([0.0396], device='cuda:0'), tensor([0.0016], device='cuda:0'), tensor([0.0467], device='cuda:0'), tensor([8.6966e-05], device='cuda:0'), tensor([0.0011], device='cuda:0'), tensor([0.0020], device='cuda:0'), tensor([6.2654e-05], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.0082], device='cuda:0'), tensor([0.0095], device='cuda:0'), tensor([0.0015], device='cuda:0'), tensor([0.0091], device='cuda:0'), tensor([0.0424], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([0.0845], device='cuda:0'), tensor([0.0081], device='cuda:0'), tensor([0.0138], device='cuda:0'), tensor([4.9915e-05], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.0736], device='cuda:0'), tensor([0.0387], device='cuda:0'), tensor([0.0834], device='cuda:0'), tensor([0.0080], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.2387], device='cuda:0'), tensor([0.0112], device='cuda:0'), tensor([4.9275e-06], device='cuda:0'), tensor([0.0324], device='cuda:0'))
# p(1.804375) = 0.029914490492168322
# (tensor([0.0015], device='cuda:0'), tensor([8.8284e-06], device='cuda:0'), tensor([0.0066], device='cuda:0'), tensor([0.0052], device='cuda:0'), tensor([0.0128], device='cuda:0'), tensor([0.0111], device='cuda:0'), tensor([1.6474e-05], device='cuda:0'), tensor([1.1267e-05], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0052], device='cuda:0'), tensor([0.0035], device='cuda:0'), tensor([0.0051], device='cuda:0'), tensor([0.1062], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0109], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.0274], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0014], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.1056], device='cuda:0'), tensor([0.0051], device='cuda:0'), tensor([0.0018], device='cuda:0'), tensor([0.0066], device='cuda:0'), tensor([0.0018], device='cuda:0'), tensor([0.0036], device='cuda:0'), tensor([0.0035], device='cuda:0'), tensor([0.0121], device='cuda:0'), tensor([0.0010], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0109], device='cuda:0'), tensor([0.0072], device='cuda:0'), tensor([0.0812], device='cuda:0'), tensor([0.0095], device='cuda:0'), tensor([0.0026], device='cuda:0'), tensor([0.3772], device='cuda:0'), tensor([0.0019], device='cuda:0'), tensor([0.0017], device='cuda:0'), tensor([0.0104], device='cuda:0'), tensor([0.0208], device='cuda:0'), tensor([0.0235], device='cuda:0'), tensor([0.0156], device='cuda:0'), tensor([6.4709e-05], device='cuda:0'), tensor([0.0285], device='cuda:0'), tensor([9.6435e-05], device='cuda:0'), tensor([1.1971e-05], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0042], device='cuda:0'), tensor([0.0010], device='cuda:0'), tensor([0.0071], device='cuda:0'))
# p(1.82) = 0.01889818515875922
# (tensor([0.0004], device='cuda:0'), tensor([0.0177], device='cuda:0'), tensor([0.0040], device='cuda:0'), tensor([0.0010], device='cuda:0'), tensor([0.0105], device='cuda:0'), tensor([0.0098], device='cuda:0'), tensor([0.0069], device='cuda:0'), tensor([0.0075], device='cuda:0'), tensor([0.0017], device='cuda:0'), tensor([0.0034], device='cuda:0'), tensor([0.0025], device='cuda:0'), tensor([0.0585], device='cuda:0'), tensor([0.0241], device='cuda:0'), tensor([0.0089], device='cuda:0'), tensor([0.2114], device='cuda:0'), tensor([4.7626e-05], device='cuda:0'), tensor([0.0149], device='cuda:0'), tensor([0.0035], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.0790], device='cuda:0'), tensor([0.0096], device='cuda:0'), tensor([0.0041], device='cuda:0'), tensor([0.0204], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0010], device='cuda:0'), tensor([0.0028], device='cuda:0'), tensor([0.0029], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0035], device='cuda:0'), tensor([0.0974], device='cuda:0'), tensor([0.0062], device='cuda:0'), tensor([0.1061], device='cuda:0'), tensor([0.0078], device='cuda:0'), tensor([0.0036], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0029], device='cuda:0'), tensor([0.0051], device='cuda:0'), tensor([0.1285], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0009], device='cuda:0'), tensor([0.6141], device='cuda:0'), tensor([0.1695], device='cuda:0'), tensor([0.0573], device='cuda:0'), tensor([0.0053], device='cuda:0'), tensor([0.0631], device='cuda:0'), tensor([1.2313e-05], device='cuda:0'), tensor([0.0112], device='cuda:0'), tensor([0.0014], device='cuda:0'), tensor([0.1593], device='cuda:0'), tensor([0.0224], device='cuda:0'))
# p(1.835625) = 0.03948061610654655
# (tensor([0.0107], device='cuda:0'), tensor([0.1398], device='cuda:0'), tensor([0.0023], device='cuda:0'), tensor([0.0056], device='cuda:0'), tensor([1.9202e-05], device='cuda:0'), tensor([0.0647], device='cuda:0'), tensor([0.0019], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([0.0040], device='cuda:0'), tensor([0.0101], device='cuda:0'), tensor([0.0175], device='cuda:0'), tensor([9.2801e-05], device='cuda:0'), tensor([0.0107], device='cuda:0'), tensor([0.0139], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0585], device='cuda:0'), tensor([0.0025], device='cuda:0'), tensor([0.0060], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0801], device='cuda:0'), tensor([0.6086], device='cuda:0'), tensor([0.0210], device='cuda:0'), tensor([0.0229], device='cuda:0'), tensor([0.0025], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0835], device='cuda:0'), tensor([0.0221], device='cuda:0'), tensor([2.5420e-06], device='cuda:0'), tensor([0.0050], device='cuda:0'), tensor([0.1198], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0031], device='cuda:0'), tensor([0.0068], device='cuda:0'), tensor([0.2658], device='cuda:0'), tensor([0.2488], device='cuda:0'), tensor([0.3403], device='cuda:0'), tensor([0.0266], device='cuda:0'), tensor([0.0261], device='cuda:0'), tensor([0.0096], device='cuda:0'), tensor([0.0020], device='cuda:0'), tensor([0.2135], device='cuda:0'), tensor([0.2322], device='cuda:0'), tensor([0.0860], device='cuda:0'), tensor([9.8953e-05], device='cuda:0'), tensor([0.0749], device='cuda:0'), tensor([8.9594e-05], device='cuda:0'), tensor([0.0026], device='cuda:0'), tensor([0.0015], device='cuda:0'), tensor([0.0020], device='cuda:0'), tensor([0.0015], device='cuda:0'))
# p(1.85125) = 0.05718229812296995
# (tensor([0.0219], device='cuda:0'), tensor([0.0091], device='cuda:0'), tensor([3.3822e-05], device='cuda:0'), tensor([0.0042], device='cuda:0'), tensor([0.3129], device='cuda:0'), tensor([0.0085], device='cuda:0'), tensor([0.0118], device='cuda:0'), tensor([0.0018], device='cuda:0'), tensor([0.0971], device='cuda:0'), tensor([0.0763], device='cuda:0'), tensor([0.0053], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0052], device='cuda:0'), tensor([0.1860], device='cuda:0'), tensor([0.0020], device='cuda:0'), tensor([0.0103], device='cuda:0'), tensor([0.0056], device='cuda:0'), tensor([0.0267], device='cuda:0'), tensor([0.0022], device='cuda:0'), tensor([0.0672], device='cuda:0'), tensor([0.0212], device='cuda:0'), tensor([0.0230], device='cuda:0'), tensor([0.0048], device='cuda:0'), tensor([0.0085], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([1.9260e-05], device='cuda:0'), tensor([0.0016], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0049], device='cuda:0'), tensor([1.9091e-05], device='cuda:0'), tensor([0.0124], device='cuda:0'), tensor([0.0126], device='cuda:0'), tensor([0.0050], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0017], device='cuda:0'), tensor([0.0019], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0122], device='cuda:0'), tensor([0.0019], device='cuda:0'), tensor([0.0183], device='cuda:0'), tensor([0.0100], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0339], device='cuda:0'), tensor([0.0031], device='cuda:0'), tensor([0.0314], device='cuda:0'), tensor([0.8683], device='cuda:0'), tensor([0.0038], device='cuda:0'), tensor([0.0335], device='cuda:0'))
# p(1.866875) = 0.03943916137314091
# (tensor([0.2248], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0285], device='cuda:0'), tensor([0.0106], device='cuda:0'), tensor([0.0405], device='cuda:0'), tensor([0.0017], device='cuda:0'), tensor([0.0104], device='cuda:0'), tensor([0.0232], device='cuda:0'), tensor([0.0311], device='cuda:0'), tensor([5.7476e-05], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.6879], device='cuda:0'), tensor([0.0012], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0049], device='cuda:0'), tensor([0.6182], device='cuda:0'), tensor([0.0023], device='cuda:0'), tensor([0.0137], device='cuda:0'), tensor([0.0102], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.5954], device='cuda:0'), tensor([0.0067], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0107], device='cuda:0'), tensor([0.0015], device='cuda:0'), tensor([7.0821e-05], device='cuda:0'), tensor([0.0144], device='cuda:0'), tensor([0.1495], device='cuda:0'), tensor([0.0092], device='cuda:0'), tensor([0.0116], device='cuda:0'), tensor([0.0272], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.0010], device='cuda:0'), tensor([0.0011], device='cuda:0'), tensor([0.0013], device='cuda:0'), tensor([0.0047], device='cuda:0'), tensor([0.1263], device='cuda:0'), tensor([0.0229], device='cuda:0'), tensor([0.0006], device='cuda:0'), tensor([0.0818], device='cuda:0'), tensor([0.1123], device='cuda:0'), tensor([0.0169], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0094], device='cuda:0'), tensor([0.0820], device='cuda:0'), tensor([0.0010], device='cuda:0'), tensor([0.0072], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.1114], device='cuda:0'), tensor([0.0005], device='cuda:0'))
# p(1.8825) = 0.06237999358706562
# (tensor([0.0003], device='cuda:0'), tensor([0.0021], device='cuda:0'), tensor([0.0027], device='cuda:0'), tensor([0.0018], device='cuda:0'), tensor([0.0160], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0038], device='cuda:0'), tensor([0.0015], device='cuda:0'), tensor([0.0073], device='cuda:0'), tensor([0.0153], device='cuda:0'), tensor([0.0224], device='cuda:0'), tensor([0.0146], device='cuda:0'), tensor([0.0636], device='cuda:0'), tensor([2.2333e-05], device='cuda:0'), tensor([0.1112], device='cuda:0'), tensor([0.0015], device='cuda:0'), tensor([0.2175], device='cuda:0'), tensor([0.0150], device='cuda:0'), tensor([0.0055], device='cuda:0'), tensor([0.1704], device='cuda:0'), tensor([0.0105], device='cuda:0'), tensor([0.0641], device='cuda:0'), tensor([0.2247], device='cuda:0'), tensor([0.0069], device='cuda:0'), tensor([0.0583], device='cuda:0'), tensor([0.0072], device='cuda:0'), tensor([8.4695e-05], device='cuda:0'), tensor([0.0584], device='cuda:0'), tensor([0.0466], device='cuda:0'), tensor([0.0034], device='cuda:0'), tensor([0.0167], device='cuda:0'), tensor([0.0081], device='cuda:0'), tensor([0.0058], device='cuda:0'), tensor([0.0021], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0057], device='cuda:0'), tensor([0.0111], device='cuda:0'), tensor([0.0238], device='cuda:0'), tensor([0.0017], device='cuda:0'), tensor([0.5929], device='cuda:0'), tensor([0.5736], device='cuda:0'), tensor([0.3522], device='cuda:0'), tensor([0.0147], device='cuda:0'), tensor([0.0012], device='cuda:0'), tensor([0.0019], device='cuda:0'), tensor([0.0014], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0018], device='cuda:0'), tensor([0.2681], device='cuda:0'), tensor([0.0158], device='cuda:0'))
# p(1.898125) = 0.061048693802324396
# (tensor([0.0108], device='cuda:0'), tensor([0.0149], device='cuda:0'), tensor([0.6002], device='cuda:0'), tensor([0.1257], device='cuda:0'), tensor([0.2400], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0107], device='cuda:0'), tensor([0.0730], device='cuda:0'), tensor([0.0031], device='cuda:0'), tensor([0.0041], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0106], device='cuda:0'), tensor([0.0360], device='cuda:0'), tensor([0.2434], device='cuda:0'), tensor([0.0226], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0151], device='cuda:0'), tensor([0.0280], device='cuda:0'), tensor([0.0017], device='cuda:0'), tensor([0.0495], device='cuda:0'), tensor([0.0083], device='cuda:0'), tensor([0.0061], device='cuda:0'), tensor([0.0673], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0276], device='cuda:0'), tensor([0.2925], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.5494], device='cuda:0'), tensor([0.0035], device='cuda:0'), tensor([0.0909], device='cuda:0'), tensor([0.0048], device='cuda:0'), tensor([0.3429], device='cuda:0'), tensor([0.8011], device='cuda:0'), tensor([0.1402], device='cuda:0'), tensor([0.0718], device='cuda:0'), tensor([0.0005], device='cuda:0'), tensor([0.0016], device='cuda:0'), tensor([0.0064], device='cuda:0'), tensor([0.0096], device='cuda:0'), tensor([0.0033], device='cuda:0'), tensor([0.0586], device='cuda:0'), tensor([0.1210], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([0.0044], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.2825], device='cuda:0'), tensor([0.0575], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0054], device='cuda:0'), tensor([0.0231], device='cuda:0'))
# p(1.91375) = 0.08946327964127498
# (tensor([0.0393], device='cuda:0'), tensor([0.0012], device='cuda:0'), tensor([0.0039], device='cuda:0'), tensor([0.0001], device='cuda:0'), tensor([0.0071], device='cuda:0'), tensor([0.0722], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0030], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0015], device='cuda:0'), tensor([0.0331], device='cuda:0'), tensor([0.0171], device='cuda:0'), tensor([0.6205], device='cuda:0'), tensor([0.0010], device='cuda:0'), tensor([0.0412], device='cuda:0'), tensor([0.0056], device='cuda:0'), tensor([0.0284], device='cuda:0'), tensor([0.0032], device='cuda:0'), tensor([0.0007], device='cuda:0'), tensor([0.0453], device='cuda:0'), tensor([0.1593], device='cuda:0'), tensor([0.2937], device='cuda:0'), tensor([0.0035], device='cuda:0'), tensor([0.0087], device='cuda:0'), tensor([0.0215], device='cuda:0'), tensor([0.0030], device='cuda:0'), tensor([0.0044], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0106], device='cuda:0'), tensor([0.0031], device='cuda:0'), tensor([0.0179], device='cuda:0'), tensor([0.0367], device='cuda:0'), tensor([0.0054], device='cuda:0'), tensor([0.0012], device='cuda:0'), tensor([0.0683], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([0.0030], device='cuda:0'), tensor([0.0028], device='cuda:0'), tensor([0.0235], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0827], device='cuda:0'), tensor([0.1962], device='cuda:0'), tensor([0.0526], device='cuda:0'), tensor([0.0010], device='cuda:0'), tensor([0.0029], device='cuda:0'), tensor([0.1008], device='cuda:0'), tensor([0.0022], device='cuda:0'), tensor([0.0612], device='cuda:0'), tensor([8.3403e-06], device='cuda:0'), tensor([0.0025], device='cuda:0'))
# p(1.929375) = 0.04189031347647514
# (tensor([0.0068], device='cuda:0'), tensor([0.0465], device='cuda:0'), tensor([0.0098], device='cuda:0'), tensor([0.0310], device='cuda:0'), tensor([0.0085], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0056], device='cuda:0'), tensor([0.0699], device='cuda:0'), tensor([0.1541], device='cuda:0'), tensor([0.0055], device='cuda:0'), tensor([5.2397e-05], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0059], device='cuda:0'), tensor([0.0520], device='cuda:0'), tensor([0.0105], device='cuda:0'), tensor([0.0585], device='cuda:0'), tensor([0.0148], device='cuda:0'), tensor([0.0292], device='cuda:0'), tensor([0.4610], device='cuda:0'), tensor([0.0077], device='cuda:0'), tensor([0.0221], device='cuda:0'), tensor([0.2537], device='cuda:0'), tensor([0.0336], device='cuda:0'), tensor([0.2950], device='cuda:0'), tensor([0.0243], device='cuda:0'), tensor([0.0392], device='cuda:0'), tensor([0.0016], device='cuda:0'), tensor([0.0525], device='cuda:0'), tensor([0.0164], device='cuda:0'), tensor([0.0020], device='cuda:0'), tensor([0.0682], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0008], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.2478], device='cuda:0'), tensor([0.0028], device='cuda:0'), tensor([0.0169], device='cuda:0'), tensor([0.0030], device='cuda:0'), tensor([0.0074], device='cuda:0'), tensor([0.2061], device='cuda:0'), tensor([0.0449], device='cuda:0'), tensor([0.0003], device='cuda:0'), tensor([0.0024], device='cuda:0'), tensor([0.0184], device='cuda:0'), tensor([4.3072e-05], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([0.0562], device='cuda:0'), tensor([0.2831], device='cuda:0'), tensor([0.0006], device='cuda:0'))
# p(1.945) = 0.05358573367038636
# ...
# p(4.585625) = 0.21972776867774205
# (tensor([6.1458e-137], device='cuda:0'), tensor([1.0287e-48], device='cuda:0'), tensor([1.5913e-94], device='cuda:0'), tensor([4.7167e-66], device='cuda:0'), tensor([9.4398e-56], device='cuda:0'), tensor([2.0113e-93], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([1.6356e-35], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([6.0311e-139], device='cuda:0'), tensor([1.5178e-63], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([3.0615e-59], device='cuda:0'), tensor([8.9570e-57], device='cuda:0'), tensor([3.4683e-22], device='cuda:0'), tensor([2.4785e-61], device='cuda:0'), tensor([4.3447e-32], device='cuda:0'), tensor([1.4274e-74], device='cuda:0'), tensor([1.4044e-45], device='cuda:0'), tensor([9.3942e-85], device='cuda:0'), tensor([8.0612e-51], device='cuda:0'), tensor([4.0594e-68], device='cuda:0'), tensor([4.3663e-17], device='cuda:0'), tensor([2.6365e-50], device='cuda:0'), tensor([0.9908], device='cuda:0'), tensor([0.9967], device='cuda:0'), tensor([1.8573e-80], device='cuda:0'), tensor([1.8252e-75], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([4.5306e-61], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([1.0000], device='cuda:0'), tensor([4.8712e-68], device='cuda:0'), tensor([2.9613e-34], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([2.1367e-05], device='cuda:0'), tensor([1.2871e-123], device='cuda:0'), tensor([3.0199e-57], device='cuda:0'), tensor([0.9988], device='cuda:0'), tensor([5.2606e-81], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([7.2505e-15], device='cuda:0'), tensor([6.4371e-91], device='cuda:0'), tensor([2.6103e-33], device='cuda:0'), tensor([2.7209e-51], device='cuda:0'), tensor([1.0000], device='cuda:0'), tensor([2.9340e-62], device='cuda:0'), tensor([1.9637e-87], device='cuda:0'), tensor([6.9632e-33], device='cuda:0'), tensor([3.3967e-88], device='cuda:0'))
# p(4.60125) = 0.23972481040745117
# (tensor([1.6182e-78], device='cuda:0'), tensor([2.6242e-27], device='cuda:0'), tensor([0.9728], device='cuda:0'), tensor([5.4243e-75], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([5.3061e-26], device='cuda:0'), tensor([1.0690e-19], device='cuda:0'), tensor([1.5078e-82], device='cuda:0'), tensor([1.9156e-153], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([3.7397e-37], device='cuda:0'), tensor([1.4139e-117], device='cuda:0'), tensor([7.9130e-116], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([3.6850e-89], device='cuda:0'), tensor([8.1484e-41], device='cuda:0'), tensor([1.0310e-93], device='cuda:0'), tensor([3.6224e-84], device='cuda:0'), tensor([6.7723e-119], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([7.7544e-148], device='cuda:0'), tensor([3.3149e-31], device='cuda:0'), tensor([3.2754e-05], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([6.2775e-07], device='cuda:0'), tensor([2.1657e-27], device='cuda:0'), tensor([4.4541e-47], device='cuda:0'), tensor([1.7379e-120], device='cuda:0'), tensor([1.0780e-55], device='cuda:0'), tensor([3.1950e-41], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([8.0869e-20], device='cuda:0'), tensor([4.3043e-44], device='cuda:0'), tensor([2.9777e-21], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([2.0006e-07], device='cuda:0'), tensor([5.1947e-37], device='cuda:0'), tensor([3.9133e-76], device='cuda:0'), tensor([5.9814e-36], device='cuda:0'), tensor([3.1195e-37], device='cuda:0'), tensor([1.0000], device='cuda:0'), tensor([8.9122e-16], device='cuda:0'), tensor([4.8160e-73], device='cuda:0'), tensor([1.6765e-38], device='cuda:0'), tensor([1.6804e-13], device='cuda:0'), tensor([1.0871e-25], device='cuda:0'), tensor([2.5233e-69], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([2.5187e-45], device='cuda:0'), tensor([1.0197e-119], device='cuda:0'))
# p(4.616875) = 0.19945714936977496
# (tensor([1.], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([1.9246e-33], device='cuda:0'), tensor([3.0283e-53], device='cuda:0'), tensor([2.2653e-103], device='cuda:0'), tensor([1.7705e-132], device='cuda:0'), tensor([1.3472e-36], device='cuda:0'), tensor([6.4070e-53], device='cuda:0'), tensor([4.2254e-34], device='cuda:0'), tensor([5.3464e-34], device='cuda:0'), tensor([2.2502e-89], device='cuda:0'), tensor([2.3146e-19], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([1.5265e-60], device='cuda:0'), tensor([2.5945e-22], device='cuda:0'), tensor([6.3716e-67], device='cuda:0'), tensor([2.0196e-12], device='cuda:0'), tensor([5.1903e-77], device='cuda:0'), tensor([1.4085e-84], device='cuda:0'), tensor([3.4280e-109], device='cuda:0'), tensor([1.4524e-23], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([1.2885e-34], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([1.7279e-100], device='cuda:0'), tensor([1.7862e-53], device='cuda:0'), tensor([1.6867e-66], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([9.4906e-138], device='cuda:0'), tensor([1.0485e-58], device='cuda:0'), tensor([1.3962e-27], device='cuda:0'), tensor([7.9671e-25], device='cuda:0'), tensor([7.3515e-66], device='cuda:0'), tensor([1.1121e-127], device='cuda:0'), tensor([2.7312e-26], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([9.3650e-98], device='cuda:0'), tensor([1.5409e-38], device='cuda:0'), tensor([5.7395e-99], device='cuda:0'), tensor([1.0000], device='cuda:0'), tensor([1.1952e-10], device='cuda:0'), tensor([5.7103e-94], device='cuda:0'), tensor([9.5565e-20], device='cuda:0'), tensor([8.9976e-58], device='cuda:0'), tensor([3.4966e-49], device='cuda:0'), tensor([2.5740e-99], device='cuda:0'), tensor([4.9509e-117], device='cuda:0'), tensor([1.5536e-108], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([6.5963e-12], device='cuda:0'))
# p(4.6325) = 0.16000322384965557
# (tensor([2.2470e-16], device='cuda:0'), tensor([3.8049e-89], device='cuda:0'), tensor([3.4534e-122], device='cuda:0'), tensor([6.3861e-49], device='cuda:0'), tensor([3.5730e-77], device='cuda:0'), tensor([6.2981e-21], device='cuda:0'), tensor([3.8114e-53], device='cuda:0'), tensor([2.3629e-85], device='cuda:0'), tensor([1.0000], device='cuda:0'), tensor([5.9701e-48], device='cuda:0'), tensor([3.3129e-60], device='cuda:0'), tensor([5.7419e-38], device='cuda:0'), tensor([4.8907e-83], device='cuda:0'), tensor([3.1306e-11], device='cuda:0'), tensor([9.5317e-86], device='cuda:0'), tensor([6.4885e-126], device='cuda:0'), tensor([2.8445e-69], device='cuda:0'), tensor([2.6352e-10], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([4.4146e-71], device='cuda:0'), tensor([0.0706], device='cuda:0'), tensor([5.0861e-159], device='cuda:0'), tensor([1.0950e-106], device='cuda:0'), tensor([0.0018], device='cuda:0'), tensor([7.2943e-103], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([1.8789e-12], device='cuda:0'), tensor([5.5218e-61], device='cuda:0'), tensor([1.2305e-31], device='cuda:0'), tensor([8.0568e-98], device='cuda:0'), tensor([2.1807e-107], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([2.3137e-52], device='cuda:0'), tensor([6.4158e-19], device='cuda:0'), tensor([8.2708e-53], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([9.8924e-21], device='cuda:0'), tensor([5.4073e-08], device='cuda:0'), tensor([3.7449e-28], device='cuda:0'), tensor([7.9692e-186], device='cuda:0'), tensor([1.9131e-43], device='cuda:0'), tensor([2.4715e-92], device='cuda:0'), tensor([1.7964e-59], device='cuda:0'), tensor([1.6466e-92], device='cuda:0'), tensor([6.5031e-65], device='cuda:0'), tensor([3.9754e-32], device='cuda:0'), tensor([1.3955e-15], device='cuda:0'), tensor([2.6027e-72], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([9.3307e-32], device='cuda:0'))
# p(4.648125) = 0.1214475339015863
# (tensor([1.], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([7.9756e-120], device='cuda:0'), tensor([6.1490e-34], device='cuda:0'), tensor([5.4620e-87], device='cuda:0'), tensor([1.9186e-94], device='cuda:0'), tensor([0.9961], device='cuda:0'), tensor([1.9555e-25], device='cuda:0'), tensor([1.1346e-23], device='cuda:0'), tensor([1.5872e-74], device='cuda:0'), tensor([0.0004], device='cuda:0'), tensor([2.0836e-115], device='cuda:0'), tensor([6.8366e-30], device='cuda:0'), tensor([6.2590e-159], device='cuda:0'), tensor([7.4999e-53], device='cuda:0'), tensor([1.0492e-73], device='cuda:0'), tensor([1.5135e-85], device='cuda:0'), tensor([0.9981], device='cuda:0'), tensor([1.8160e-22], device='cuda:0'), tensor([1.6395e-33], device='cuda:0'), tensor([5.5483e-44], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([8.6481e-110], device='cuda:0'), tensor([3.1164e-82], device='cuda:0'), tensor([2.0311e-32], device='cuda:0'), tensor([2.3835e-35], device='cuda:0'), tensor([8.4491e-23], device='cuda:0'), tensor([2.8065e-110], device='cuda:0'), tensor([4.7652e-48], device='cuda:0'), tensor([8.0402e-50], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([0.9879], device='cuda:0'), tensor([2.8725e-134], device='cuda:0'), tensor([2.4011e-11], device='cuda:0'), tensor([2.6033e-07], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([2.7191e-74], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([1.1750e-31], device='cuda:0'), tensor([0.0002], device='cuda:0'), tensor([1.3531e-192], device='cuda:0'), tensor([1.9040e-57], device='cuda:0'), tensor([2.4508e-53], device='cuda:0'), tensor([2.0043e-53], device='cuda:0'), tensor([3.8954e-55], device='cuda:0'), tensor([1.6401e-107], device='cuda:0'), tensor([4.4129e-74], device='cuda:0'), tensor([9.0697e-09], device='cuda:0'), tensor([2.9498e-13], device='cuda:0'), tensor([8.3471e-35], device='cuda:0'))
# p(4.66375) = 0.1796520077419396
# (tensor([2.6059e-38], device='cuda:0'), tensor([5.6081e-78], device='cuda:0'), tensor([1.8978e-69], device='cuda:0'), tensor([7.2895e-05], device='cuda:0'), tensor([3.0913e-47], device='cuda:0'), tensor([9.1841e-93], device='cuda:0'), tensor([3.4324e-65], device='cuda:0'), tensor([4.0344e-45], device='cuda:0'), tensor([2.4578e-113], device='cuda:0'), tensor([2.3477e-134], device='cuda:0'), tensor([6.9011e-25], device='cuda:0'), tensor([4.5861e-24], device='cuda:0'), tensor([2.6984e-10], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([4.7923e-55], device='cuda:0'), tensor([5.9547e-128], device='cuda:0'), tensor([8.1648e-47], device='cuda:0'), tensor([1.1000e-17], device='cuda:0'), tensor([7.0060e-41], device='cuda:0'), tensor([2.0023e-92], device='cuda:0'), tensor([8.7792e-41], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([4.6292e-77], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([1.9593e-81], device='cuda:0'), tensor([5.9816e-125], device='cuda:0'), tensor([0.8894], device='cuda:0'), tensor([9.3320e-154], device='cuda:0'), tensor([2.3249e-09], device='cuda:0'), tensor([1.0000], device='cuda:0'), tensor([3.6421e-23], device='cuda:0'), tensor([2.0982e-50], device='cuda:0'), tensor([1.4127e-68], device='cuda:0'), tensor([4.5670e-90], device='cuda:0'), tensor([2.3164e-134], device='cuda:0'), tensor([1.1382e-88], device='cuda:0'), tensor([8.5368e-134], device='cuda:0'), tensor([3.6447e-79], device='cuda:0'), tensor([3.7139e-65], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([5.8240e-45], device='cuda:0'), tensor([1.9696e-10], device='cuda:0'), tensor([1.3823e-115], device='cuda:0'), tensor([1.0000], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([4.2446e-47], device='cuda:0'), tensor([4.7105e-86], device='cuda:0'), tensor([0.4535], device='cuda:0'), tensor([1.0000], device='cuda:0'), tensor([2.9056e-84], device='cuda:0'))
# p(4.679375) = 0.1868611618889157
# (tensor([2.1906e-61], device='cuda:0'), tensor([1.9990e-97], device='cuda:0'), tensor([7.0167e-14], device='cuda:0'), tensor([2.2340e-80], device='cuda:0'), tensor([1.2858e-14], device='cuda:0'), tensor([1.9575e-14], device='cuda:0'), tensor([1.9634e-117], device='cuda:0'), tensor([1.0000], device='cuda:0'), tensor([1.0000], device='cuda:0'), tensor([1.5360e-101], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([4.7700e-41], device='cuda:0'), tensor([5.8771e-42], device='cuda:0'), tensor([4.3282e-162], device='cuda:0'), tensor([1.0000], device='cuda:0'), tensor([1.0884e-48], device='cuda:0'), tensor([1.0957e-99], device='cuda:0'), tensor([6.5861e-110], device='cuda:0'), tensor([1.8813e-123], device='cuda:0'), tensor([1.2264e-06], device='cuda:0'), tensor([1.0000], device='cuda:0'), tensor([1.0754e-26], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([9.5881e-69], device='cuda:0'), tensor([6.8666e-42], device='cuda:0'), tensor([6.8472e-25], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([7.7325e-69], device='cuda:0'), tensor([1.1781e-158], device='cuda:0'), tensor([1.0239e-46], device='cuda:0'), tensor([2.2207e-168], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([2.3063e-05], device='cuda:0'), tensor([1.4954e-61], device='cuda:0'), tensor([2.8790e-54], device='cuda:0'), tensor([1.0682e-15], device='cuda:0'), tensor([1.6142e-99], device='cuda:0'), tensor([9.9463e-148], device='cuda:0'), tensor([6.0204e-61], device='cuda:0'), tensor([3.7069e-29], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([3.3280e-102], device='cuda:0'), tensor([2.5822e-89], device='cuda:0'), tensor([4.4243e-29], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([1.5720e-78], device='cuda:0'), tensor([3.5716e-62], device='cuda:0'), tensor([5.1167e-66], device='cuda:0'), tensor([8.7344e-58], device='cuda:0'), tensor([1.], device='cuda:0'))
# p(4.695) = 0.22000041451008792
# (tensor([7.9007e-161], device='cuda:0'), tensor([2.0742e-56], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([5.7625e-90], device='cuda:0'), tensor([1.4674e-34], device='cuda:0'), tensor([0.8572], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([1.6997e-49], device='cuda:0'), tensor([2.0192e-103], device='cuda:0'), tensor([1.0000], device='cuda:0'), tensor([9.4757e-47], device='cuda:0'), tensor([1.7658e-45], device='cuda:0'), tensor([6.7724e-193], device='cuda:0'), tensor([4.5491e-32], device='cuda:0'), tensor([2.4266e-88], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([3.6640e-85], device='cuda:0'), tensor([4.0593e-102], device='cuda:0'), tensor([3.9528e-68], device='cuda:0'), tensor([3.7109e-133], device='cuda:0'), tensor([1.0617e-79], device='cuda:0'), tensor([0.9087], device='cuda:0'), tensor([1.4892e-67], device='cuda:0'), tensor([1.0562e-77], device='cuda:0'), tensor([4.2808e-56], device='cuda:0'), tensor([0.7600], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([1.4565e-75], device='cuda:0'), tensor([9.2620e-72], device='cuda:0'), tensor([2.5890e-86], device='cuda:0'), tensor([1.2542e-60], device='cuda:0'), tensor([4.1794e-73], device='cuda:0'), tensor([1.7395e-134], device='cuda:0'), tensor([1.], device='cuda:0'), tensor([1.2445e-20], device='cuda:0'), tensor([3.8771e-42], device='cuda:0'), tensor([2.0804e-09], device='cuda:0'), tensor([1.0000], device='cuda:0'), tensor([2.0102e-70], device='cuda:0'), tensor([1.0502e-27], device='cuda:0'), tensor([1.4289e-177], device='cuda:0'), tensor([7.9919e-42], device='cuda:0'), tensor([2.2297e-144], device='cuda:0'), tensor([1.4387e-60], device='cuda:0'), tensor([1.4511e-92], device='cuda:0'), tensor([3.4414e-38], device='cuda:0'), tensor([0.2332], device='cuda:0'), tensor([1.9891e-38], device='cuda:0'), tensor([3.8361e-64], device='cuda:0'), tensor([7.1345e-53], device='cuda:0'))
# p(4.710625) = 0.19518190659607995

# %%
# filename_det = f"/content/drive/MyDrive/model_params_batch_{env_train_det['batch_n']}_epochs_{env_train_det['training_epochs']}_{env_train_det['params_name']}"

# env_load_det = {
#             "params_name": None,
#             "params_load": filename_det,
#             "params_load_batch": None,
#             "sample_quantity": 10
# }

# print(filename_det)

# env_utilise_det = env_train_det | env_load_det

# %%
loss_f_out = [
  0.6702
]

# 2. Generate ascending integer values for the x-axis
# This creates a sequence from 0 to 9 based on the data length
x_values = range(len(loss_f_out))

# 3. Create the plot
plt.plot(x_values, loss_f_out, marker='o', markersize=1.5, linestyle='-', linewidth=0.5, color='black')

# 4. Add labels and title
plt.xlabel('Training epoch')
plt.ylabel('Loss function output (logarithmic)')

plt.tight_layout()

plt.yscale('log')

plt.grid(True, which="both", ls="-", alpha=0.5)

#plt.show()

plt.savefig('loss_func_out_per_epoch.pdf')
